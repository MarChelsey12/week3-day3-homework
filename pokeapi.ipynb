# %% [markdown]
# # Working with APIs

# %% [markdown]
# API stands for Application programming interface<br>
# APIs are a way for applications to talk to eachother<br>
# In python we use the requests package to handle the connection<br>
# <small><strong>Note: It is requests with an s not request(this is a different package)</strong></small><br>
# Most API's communicate with data in the form of JSON<br>
# JSON stands for JavaScript Object Notation

# %%
#import the packages we need:
import requests, json

# %% [markdown]
# We will be connecting to the Ergast F1 Racer API today:
# http://ergast.com/mrd/
#
# to view JSON data nicely in the Chrome browser install the extension JSONvue

# %%
help(requests)

# %%
url = "http://ergast.com/api/f1/2020/5/driverStandings.json"

# %%
#response object
response = requests.get(url)
print(response)
# Out:
# <Response [200]>

# %%
#check and make sure we got a successful response from the API
response.ok
# Out:
# True

# %%
#view the response as a JSON
response.json()
# Out:
# {'MRData': {'xmlns': 'http://ergast.com/mrd/1.4',
#   'series': 'f1',
#   'url': 'http://ergast.com/api/f1/2020/5/driverstandings.json',
#   'limit': '30',
#   'offset': '0',
#   'total': '21',
#   'StandingsTable': {'season': '2020',
#    'round': '5',
#    'StandingsLists': [{'season': '2020',
#      'round': '5',
#      'DriverStandings': [{'position': '1',
#        'positionText': '1',
#        'points': '107',
#        'wins': '3',
#        'Driver': {'driverId': 'hamilton',
#         'permanentNumber': '44',
#         'code': 'HAM',
#         'url': 'http://en.wikipedia.org/wiki/Lewis_Hamilton',
#         'givenName': 'Lewis',
#         'familyName': 'Hamilton',
#         'dateOfBirth': '1985-01-07',
#         'nationality': 'British'},
#        'Constructors': [{'constructorId': 'mercedes',
#          'url': 'http://en.wikipedia.org/wiki/Mercedes-Benz_in_Formula_One',
#          'name': 'Mercedes',
#          'nationality': 'German'}]},
#       {'position': '2',
# ...

# %%
type(response.json())
# Out:
# dict

# %%
# We only want the Driver Standings
data = response.json()["MRData"]["StandingsTable"]["StandingsLists"][0]["DriverStandings"]
data
# Out:
# [{'position': '1',
#   'positionText': '1',
#   'points': '107',
#   'wins': '3',
#   'Driver': {'driverId': 'hamilton',
#    'permanentNumber': '44',
#    'code': 'HAM',
#    'url': 'http://en.wikipedia.org/wiki/Lewis_Hamilton',
#    'givenName': 'Lewis',
#    'familyName': 'Hamilton',
#    'dateOfBirth': '1985-01-07',
#    'nationality': 'British'},
#   'Constructors': [{'constructorId': 'mercedes',
#     'url': 'http://en.wikipedia.org/wiki/Mercedes-Benz_in_Formula_One',
#     'name': 'Mercedes',
#     'nationality': 'German'}]},
#  {'position': '2',
#   'positionText': '2',
#   'points': '77',
#   'wins': '1',
#   'Driver': {'driverId': 'max_verstappen',
#    'permanentNumber': '33',
#    'code': 'VER',
#    'url': 'http://en.wikipedia.org/wiki/Max_Verstappen',
#    'givenName': 'Max',
#    'familyName': 'Verstappen',
#    'dateOfBirth': '1997-09-30',
#    'nationality': 'Dutch'},
#   'Constructors': [{'constructorId': 'red_bull',
# ...

# %%
type(data)

# %%
def get_racer_info(data):
    new_data=[]
    for racer in data:
        racer_dict={}
        racer_name = f"{racer['Driver']['givenName']} {racer['Driver']['familyName']}"
        
        racer_dict[racer_name]={
            'first_name':racer['Driver']['givenName'],
            'last_name':racer['Driver']['familyName'],
            'position':racer['position'],
            'wins':racer['wins'],
            'DOB':racer['Driver']['dateOfBirth'],
            'nationality':racer['Driver']['nationality'],
            'contructor':racer['Constructors'][0]['name']
        }
        new_data.append(racer_dict)
    return new_data

get_racer_info(data)
# Out:
# [{'Lewis Hamilton': {'first_name': 'Lewis',
#    'last_name': 'Hamilton',
#    'position': '1',
#    'wins': '3',
#    'DOB': '1985-01-07',
#    'nationality': 'British',
#    'contructor': 'Mercedes'}},
#  {'Max Verstappen': {'first_name': 'Max',
#    'last_name': 'Verstappen',
#    'position': '2',
#    'wins': '1',
#    'DOB': '1997-09-30',
#    'nationality': 'Dutch',
#    'contructor': 'Red Bull'}},
#  {'Valtteri Bottas': {'first_name': 'Valtteri',
#    'last_name': 'Bottas',
#    'position': '3',
#    'wins': '1',
#    'DOB': '1989-08-28',
#    'nationality': 'Finnish',
#    'contructor': 'Mercedes'}},
#  {'Charles Leclerc': {'first_name': 'Charles',
#    'last_name': 'Leclerc',
#    'position': '4',
#    'wins': '0',
#    'DOB': '1997-10-16',
#    'nationality': 'Monegasque',
#    'contructor': 'Ferrari'}},
#  {'Lando Norris': {'first_name': 'Lando',
#    'last_name': 'Norris',
#    'position': '5',
#    'wins': '0',
#    'DOB': '1999-11-13',
#    'nationality': 'British',
# ...

# %%
def get_driver_info_by_year_and_round(year,r):
    url = f"http://ergast.com/api/f1/{year}/{r}/driverStandings.json"
    response = requests.get(url)
#     if not response.ok:
    if not response.json()["MRData"]["StandingsTable"]["StandingsLists"]:
        return "We had an error loading your data likely the year or round is not in the database"
    data = response.json()["MRData"]["StandingsTable"]["StandingsLists"][0]["DriverStandings"]
    return get_racer_info(data)

get_driver_info_by_year_and_round(2020,3)[0:4]
# Out:
# [{'Lewis Hamilton': {'first_name': 'Lewis',
#    'last_name': 'Hamilton',
#    'position': '1',
#    'wins': '2',
#    'DOB': '1985-01-07',
#    'nationality': 'British',
#    'contructor': 'Mercedes'}},
#  {'Valtteri Bottas': {'first_name': 'Valtteri',
#    'last_name': 'Bottas',
#    'position': '2',
#    'wins': '1',
#    'DOB': '1989-08-28',
#    'nationality': 'Finnish',
#    'contructor': 'Mercedes'}},
#  {'Max Verstappen': {'first_name': 'Max',
#    'last_name': 'Verstappen',
#    'position': '3',
#    'wins': '0',
#    'DOB': '1997-09-30',
#    'nationality': 'Dutch',
#    'contructor': 'Red Bull'}},
#  {'Lando Norris': {'first_name': 'Lando',
#    'last_name': 'Norris',
#    'position': '4',
#    'wins': '0',
#    'DOB': '1999-11-13',
#    'nationality': 'British',
#    'contructor': 'McLaren'}}]

# %% [markdown]
# # <strong>Homework</strong>
# check out this Pokemon API https://pokeapi.co/
# Use the requests package to connect to this API and get and store data for 5 different pokemon.
# Get the pokemons: name, atleast one ability's name, base_experience, and the URL for its sprite (an image that shows up on screen) for the 'front_shiny'

# %%
# name, atleast one ability's name, base_experience, and the URL for its sprite
def catchem_all(pokemon):
    url = f"https://pokeapi.co/api/v2/pokemon/{pokemon}"
    response = requests.get(url)
    if response.ok:
        pokedex = {
            "name":response.json()['forms'][0]['name'],
            "ability":response.json()['abilities'][0]['ability']['name'],
            "base xp":response.json()['base_experience'],
            "sprite": response.json()['sprites']['front_shiny']
        }
        return pokedex
    else:
        print("You entered in a Pokemon that doesn't exist.... guess your too old to pay. ")

catchem_all('poliwag')

my_fighters= ['flareon', 'pachirisu', 'jirachi', 'roselia', 'aurorus']

def ash_catchem(my_list):
    for items in my_fighters:
        print(catchem_all(items))
        
ash_catchem(my_fighters)
# Out:
# {'name': 'flareon', 'ability': 'flash-fire', 'base xp': 184, 'sprite': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/shiny/136.png'}
# {'name': 'pachirisu', 'ability': 'run-away', 'base xp': 142, 'sprite': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/shiny/417.png'}
# {'name': 'jirachi', 'ability': 'serene-grace', 'base xp': 270, 'sprite': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/shiny/385.png'}
# {'name': 'roselia', 'ability': 'natural-cure', 'base xp': 140, 'sprite': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/shiny/315.png'}
# {'name': 'aurorus', 'ability': 'refrigerate', 'base xp': 104, 'sprite': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/shiny/699.png'}
